# %% [markdown]
# <a href="https://colab.research.google.com/github/luizolivato/regressao/blob/main/Tarefa_Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("moments")

library(moments)
library(ggplot2)
#### Carregando o conjunto de dados
getwd()

data <- read.csv("https://github.com/luizolivato/regressao/find/main/data-table-B7.csv",header=TRUE,
sep=",", dec=",")

# Visualizando arquivo de dados
head(data)
tail(data)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# [1] "/content"
# Warning message in scan(file = file, what = what, sep = sep, quote = quote, dec = dec, :
# “EOF within quoted string”
#   X..DOCTYPE.html.
# 1 <html lang=en data-color-mode=auto data-light-theme=light data-dark-theme=dark>
# 2   <head>
# 3     <meta charset=utf-8>
# 4   <link rel=dns-prefetch href=https://github.githubassets.com>
# 5   <link rel=dns-prefetch href=https://avatars.githubusercontent.com>
# 6   <link rel=dns-prefetch href=https://github-cloud.s3.amazonaws.com>
# ...
